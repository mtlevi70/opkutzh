# %% [markdown]
# ## Második  ZH  --  2026.05.18. 15:30

# %% [markdown]
# __NÉV:__<br>
# __Neptun:__

# %%
#Az alábbi modulok hasznosak lehetnek
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd
import random as rd
from pulp import *

# %% [markdown]
# Töltse le a moodle oldalon található zh_05_18_1530.py fájlt, és helyezze ugyanabba a mappába, ahol ez a notebook file is található. A feladatokat az ezt követő két cellában lévő kóddal lehet generálni. A Generate_task("A1") függvény generálja az első feladatot, a Generate_task("A2") pedig a másodikat. A feladatokhoz tartozó adatok a G (networkx gráf) valamint a P és Q (táblázat/pandas dataframe) változókba vannak elmentve. __Amennyiben a feladat megoldása LP felírást kíván azt pulp kód segítségével kell megadni!__ A feladatok megoldására 50 perc áll rendelkezésére. Törekedjen tömör, átlátható munkára. __Minden cellánál komment formájában jelezze, hogy melyik feladathoz tartozik. Amelyik cellánál ez nincs jelezve, azt nem vesszük figyelembe.__  Kézileg számolt megoldásokért nem jár pont, minden válaszhoz Python kód megadása + szöveges értékelés szükséges.

# %%
#Első feladat
exec(open("zh_05_18_1530.py", encoding="utf-8").read())
G = Generate_task("A1")
# Out:
# Kérem adja meg a NEPTUN kódját, majd üssön ENTER-t! F64N3I
# A G gráf egy projekthálót ír le, amelyben az 0 címkéjű csúcs a projekt kezdetét a 20 címkéjű csúcs pedig a végét jelöli.
# 1. Számolja ki a kritikus s-t utat és adja meg a kritikus tevékenységeket a networkx csomag segítségével. Mennyi idő alatt lehet befejezni a projektet legkorábban? (4p)
# 2. Meddig kell csökkenteni a kritikus út utolsó előtti tevékenységének elvégzési idejét, hogy legyen egy alternatív kritikus út? (6p)
# 3. Térjünk vissza az eredeti gráfhoz! Számolja ki az összes tevékenység mozgáshatárát és adja meg a legnagyobb mozgáshatárral rendelkező tevékenységet azok közül, amelyek nem a projekt vége (20) pontra mutatnak (10p)

# %%
#Második feladat
exec(open("zh_05_18_1530.py", encoding="utf-8").read())
P, Q = Generate_task("A2")
# Out:
# Kérem adja meg a NEPTUN kódját, majd üssön ENTER-t! F64N3I
# Egy kereskedőcég megszerezte a különböző sportesemények közvetítési jogait és most tovább szeretné értékesíteni televíziós társaságoknak. Az alábbi táblázat mutatja, hogy melyik tv mennyit hajlandó fizetni egy műsor közvetítési jogáért. Az adatok meg vannak adva dataframe (P) és táblázat (Q) formájában is.
# 1. Adjon meg egy pulp kódot, amely maximalizálja az értékesítés bevételét a kereskedőcégnek, azzal a feltétellel, hogy egyetlen csatorna sem vehet háromnál több műsort. (8p)
# 2. A Spíler 1-2-nek közös tulajdonosa van (AMC) és a Sport 1 és 2 is egy kézben van (TV2). Tegyük fel, hogy az alábbi költségvetések állnak rendelkezése
#  ktg = {"RTL":120, "AMC":106, "M4 Sport": 75, "TV2": 109}. Hogyan változik az értékesítés, ha a költségvetési korlátokat is figyelembe vesszük? (6p)
# ...
